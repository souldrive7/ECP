# %% [markdown]
# <a href="https://colab.research.google.com/github/souldrive7/ECP/blob/main/%E6%95%99%E5%B8%AB%E3%81%82%E3%82%8A%E5%AD%A6%E7%BF%92%E2%80%97%E6%9D%91%E6%9D%BE%E5%85%88%E2%80%97%E8%AC%9B%E7%BE%A9%E7%94%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([1,2,3])
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b = np.arange(8).reshape(2,4)
print('要素数:',b.size)
print('次元数:',b.ndim)
print('形状:',b.shape)
# Out:
# 要素数: 8
# 次元数: 2
# 形状: (2, 4)

# %%
b1d2 = b.flatten()
b1d2
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
b1d2 = b.reshape(-1)
b1d2
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
b1d2 = b.reshape(-1,2)
b1d2
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5],
#        [6, 7]])

# %%
b1d2.T
b1d2
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5],
#        [6, 7]])

# %%
c = np.arange(2,4,0.25).reshape(4,-1)
c
# Out:
# array([[2.  , 2.25],
#        [2.5 , 2.75],
#        [3.  , 3.25],
#        [3.5 , 3.75]])

# %%
print(b)
print(c)
bxc = np.dot(b,c)
bxc
# Out:
# [[0 1 2 3]
#  [4 5 6 7]]
# [[2.   2.25]
#  [2.5  2.75]
#  [3.   3.25]
#  [3.5  3.75]]
# array([[19. , 20.5],
#        [63. , 68.5]])

# %%
b @ c
# Out:
# array([[19. , 20.5],
#        [63. , 68.5]])

# %%
b.T * c
# Out:
# array([[ 0.  ,  9.  ],
#        [ 2.5 , 13.75],
#        [ 6.  , 19.5 ],
#        [10.5 , 26.25]])

# %%
print('det =', np.linalg.det(b @ c))
print('inv =', np.linalg.inv(b @ c))
# Out:
# det = 9.999999999999966
# inv = [[ 6.85 -2.05]
#  [-6.3   1.9 ]]

# %%
inv = np.linalg.inv(b @c)
inv
# Out:
# array([[ 6.85, -2.05],
#        [-6.3 ,  1.9 ]])

# %%
for i in range(inv.shape[0]):
    for j in range(inv.shape[1]):
        print(f'{inv[i, j]:+.3f}\t', end='')
    print()  # 各行の後に改行
# Out:
# +6.850	-2.050
# -6.300	+1.900

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# !pip install japanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 43.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize-matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=87fb59bcf76469e29c47871039a47e0caa93352c81a634fb729c2feeacd4747a
#   Stored in directory: /root/.cache/pip/wheels/da/a1/71/b8faeb93276fed10edffcca20746f1ef6f8d9e071eee8425fc
# Successfully built japanize-matplotlib
# ...

# %%
import japanize_matplotlib

# %%
df = pd.DataFrame([[466,83,122,304],[475,80,110,294]],index=['Jan','Feb'],columns=['tuna','sardines','mackerel','yellowtail'])
df
# Out:
#      tuna  sardines  mackerel  yellowtail
# Jan   466        83       122         304
# Feb   475        80       110         294

# %%
df['cuttlefish']=[143,140]
df
# Out:
#      tuna  sardines  mackerel  yellowtail  cuttlefish
# Jan   466        83       122         304         143
# Feb   475        80       110         294         140

# %%
df.loc['Mar'] = [468,84,2133,291,154]
df
# Out:
#      tuna  sardines  mackerel  yellowtail  cuttlefish
# Jan   466        83       122         304         143
# Feb   475        80       110         294         140
# Mar   468        84      2133         291         154

# %%
#df2 = pd.DataFrame([[90,651]],[87,669],[86,653],index['Jan','Feb','Mar'], columns=['Saury','sea bream'])

# %%
import pandas as pd

df2 = pd.DataFrame(
    [[90, 651], [87, 669], [86, 653]],
    index=['Jan', 'Feb', 'Mar'],
    columns=['Saury', 'sea bream']
)

# %%
df3 = pd.concat([df,df2],axis=1)

# %%
df3
# Out:
#          green_soybeans  kidney_beans  pumpkins  cucumbers  eggplants  \
# jan_beg             NaN        2643.0     622.0      982.0      861.0
# jan_mid             NaN        2297.0     556.0      824.0      825.0
# jan_end             NaN        2208.0     548.0      747.0      873.0
# jan_ave             NaN        2383.0     575.0      851.0      853.0
# feb_beg             NaN        2187.0     522.0      661.0      886.0
# feb_mid             NaN        2101.0     521.0      621.0      887.0
# feb_end             NaN        2026.0     519.0      616.0      898.0
# feb_ave             NaN        2105.0     521.0      633.0      890.0
# mar_beg             NaN        1960.0     511.0      563.0      828.0
# mar_mid             NaN        2049.0     530.0      584.0      776.0
# mar_end             NaN        1914.0     516.0      559.0      715.0
# mar_ave             NaN        1974.0     519.0      568.0      773.0
# ...

# %%
df3.size
# Out:
# 612

# %%
len(df3)
# Out:
# 51

# %%
df3.shape
# Out:
# (51, 12)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, jan_beg to Mar
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   green_soybeans    16 non-null     float64
#  1   kidney_beans      48 non-null     float64
#  2   pumpkins          48 non-null     float64
#  3   cucumbers         48 non-null     float64
#  4   eggplants         48 non-null     float64
#  5   tomatoes          48 non-null     float64
#  6   green_peppers     48 non-null     float64
#  7   apples            12 non-null     float64
#  8   apples.1          36 non-null     float64
#  9   mandarin_oranges  27 non-null     float64
#  10  Saury             3 non-null      float64
#  11  sea bream         3 non-null      float64
# dtypes: float64(12)
# memory usage: 7.2+ KB

# %%
df3.describe()
# Out:
#        green_soybeans  kidney_beans    pumpkins   cucumbers   eggplants  \
# count       16.000000     48.000000   48.000000   48.000000   48.000000
# mean      1393.062500   2272.208333  505.770833  592.687500  743.500000
# std        203.608274    243.446264   34.684131  125.536153   96.375595
# min       1214.000000   1904.000000  445.000000  426.000000  607.000000
# 25%       1235.000000   2104.000000  483.750000  506.750000  665.000000
# 50%       1294.500000   2214.500000  508.500000  569.000000  715.500000
# 75%       1507.750000   2442.500000  521.250000  662.500000  830.000000
# max       1821.000000   2852.000000  622.000000  982.000000  959.000000
#
#          tomatoes  green_peppers      apples    apples.1  mandarin_oranges  \
# count   48.000000      48.000000   12.000000   36.000000         27.000000
# mean   706.062500     958.541667  603.333333  537.027778        687.037037
# std     96.919226     124.128444   80.638738   76.301839        102.655691
# ...

# %%
df3.describe(percentiles=[0.02,0.95])
# Out:
#        green_soybeans  kidney_beans    pumpkins   cucumbers   eggplants  \
# count       16.000000     48.000000   48.000000   48.000000   48.000000
# mean      1393.062500   2272.208333  505.770833  592.687500  743.500000
# std        203.608274    243.446264   34.684131  125.536153   96.375595
# min       1214.000000   1904.000000  445.000000  426.000000  607.000000
# 2%        1216.700000   1913.400000  452.520000  429.760000  620.160000
# 50%       1294.500000   2214.500000  508.500000  569.000000  715.500000
# 95%       1732.500000   2672.650000  562.500000  826.600000  890.650000
# max       1821.000000   2852.000000  622.000000  982.000000  959.000000
#
#          tomatoes  green_peppers      apples    apples.1  mandarin_oranges  \
# count   48.000000      48.000000   12.000000   36.000000         27.000000
# mean   706.062500     958.541667  603.333333  537.027778        687.037037
# std     96.919226     124.128444   80.638738   76.301839        102.655691
# ...

# %%
df3.yellowtail
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-97e20fb74d6e> in <cell line: 0>()
# ----> 1 df3.yellowtail
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'yellowtail'

# %%
df3.loc['Feb']
# Out:
# green_soybeans        NaN
# kidney_beans          NaN
# pumpkins              NaN
# cucumbers             NaN
# eggplants             NaN
# tomatoes              NaN
# green_peppers         NaN
# apples                NaN
# apples.1              NaN
# mandarin_oranges      NaN
# Saury                87.0
# sea bream           669.0
# Name: Feb, dtype: float64

# %%
df3.at['Jan','cuttlefish']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cuttlefish'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-d692d6247533> in <cell line: 0>()
# ----> 1 df3.at['Jan','cuttlefish']
#
# ...

# %%
df3.iat[0,4]
# Out:
# 861.0

# %%
df3.loc['Jan':'Feb','sardines':'Saury']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sardines'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-d1e3e6b69315> in <cell line: 0>()
# ----> 1 df3.loc['Jan':'Feb','sardines':'Saury']
#
# ...

# %%
df3.iloc[0:2,1:6]
# Out:
#          kidney_beans  pumpkins  cucumbers  eggplants  tomatoes
# jan_beg        2643.0     622.0      982.0      861.0     756.0
# jan_mid        2297.0     556.0      824.0      825.0     665.0

# %%
import pandas as pd
df = pd.read_csv('/content/MonthlyAveragePrices_veg.csv',index_col=0)
df
# Out:
#          green_soybeans  kidney_beans  pumpkins  cucumbers  eggplants  \
# jan_beg             NaN          2643       622        982        861
# jan_mid             NaN          2297       556        824        825
# jan_end             NaN          2208       548        747        873
# jan_ave             NaN          2383       575        851        853
# feb_beg             NaN          2187       522        661        886
# feb_mid             NaN          2101       521        621        887
# feb_end             NaN          2026       519        616        898
# feb_ave             NaN          2105       521        633        890
# mar_beg             NaN          1960       511        563        828
# mar_mid             NaN          2049       530        584        776
# mar_end             NaN          1914       516        559        715
# mar_ave             NaN          1974       519        568        773
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/MonthlyAveragePrices_veg.csv',usecols=[0,2,3,4,5,6,9], index_col=0)
df

# %%
df.rename(columns={'apples.1':'apples'}, inplace=True)
df.head()

# %%
av_df = df[df.index.str.contains('.*ave')]

# %%
df.isnull().sum()

# %%
av_full = av_df.dropna(axis=1,how='all') #'any'一つでも
av_full

# %%
av_th = av_full.dropna(thresh=3, axis=1)
av_th

# %%
av_fill = av_df.fillna(av_df.mean())
av_fill

# %%
av_fill = av_df.fillna(method='ffill') #ffill前から
av_fill

# %%
av_fill = av_df.interpolate()
av_fill

# %%
av_df.style.highlight_max()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
sns.pairplot(av_fill)

# %%
av_fill['season'] = [
    'Autumn/Winter', 'Autumn/Winter', 'Autumn/Winter',
    'Spring/Summer', 'Spring/Summer', 'Spring/Summer',
    'Spring/Summer', 'Spring/Summer', 'Spring/Summer',
    'Autumn/Winter', 'Autumn/Winter', 'Autumn/Winter'
]
av_fill

# %%
sns.pairplot(av_fill, hue='season')

# %%
av_fill = av_fill.drop('season', axis=1)
plt.plot(av_fill)

# %%
av_fill = av_fill.drop('season', axis=1)

# %%
plt.plot(av_fill)

# %%
av_fill.index = np.arange(1,13)
fig,ax = plt.subplots(figsize=(12,5))
ax.plot(av_fill)

# %%
fig,ax = plt.subplots(3,1, figsize=(8,6), sharex=True)
ax[0].plot(av_fill['kidney_beans'])
ax[1].plot(av_fill.iloc[:,1:], label= av_fill.columns[1:])
ax[1].set_xlabel('month')

ax[0].annotate(
    'kidney_beans',
    xy=(2, 2100),  # アノテーションの矢印の先端
    xytext=(2.7, 2200),  # テキストの表示位置
    arrowprops=dict(facecolor='black', edgecolor='black')
)
for x,y in zip(av_fill.index,av_fill['kidney_beans']):
  ax[0].text(x, y+50, str(y), ha='center')
ax[1].legend()
fig.tight_layout()
fig.supylabel('price[yen]', x=0, ha='center')
plt.show

# %%
for i in range(len(av_fill.columns)):
  plt.bar(av_fill.index, av_fill.iloc[:,i])

# %%
width = 0.12
start = -0.3
fig,ax = plt.subplots(figsize=(8,4))
for i in range(len(av_fill.columns)):
  ax.bar(av_fill.index+start+width*i, av_fill.iloc[:,i], width=width, label=av_fill.columns[i])
ax.legend()

# %%
corr = av_fill.corr()
corr

# %%
sns.heatmap(corr, vmin=-1,vmax=1, annot=True, fmt='.3f', cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-236c14ebc620> in <cell line: 0>()
# ----> 1 sns.heatmap(corr, vmin=-1,vmax=1, annot=True, fmt='.3f', cmap='coolwarm')
#
# NameError: name 'corr' is not defined

# %%
df = pd.read_excel('/content/04-03-01.xls')

# %%
df_run = df.groupby(['学年','性別'])['50m走(秒)'].agg('mean')
df_run
# Out:
# 学年  性別
# 中1  女      9.225000
#     男      8.458333
# 中2  女      8.725000
#     男      7.875000
# 中3  女      8.600000
#     男      7.841667
# 小1  女     11.338710
#     男     10.725926
# 小2  女     10.990000
#     男     10.582143
# 小3  女     11.157143
#     男     10.246875
# 小4  女     10.106452
#     男      9.595652
# Name: 50m走(秒), dtype: float64

# %%
df_run_us = df_run.unstack('性別')
df_run_us
# Out:
# 性別          女          男
# 学年
# 中1   9.225000   8.458333
# 中2   8.725000   7.875000
# 中3   8.600000   7.841667
# 小1  11.338710  10.725926
# 小2  10.990000  10.582143
# 小3  11.157143  10.246875
# 小4  10.106452   9.595652

# %%
ind = np.append(np.arange(3,7),np.arange(0.3))
df_run_ord = df_run_us.reindex(index=df_run_us.index[ind])
df_run_ord
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-419698f0f7ab> in <cell line: 0>()
#       1 ind = np.append(np.arange(3,7),np.arange(0.3))
# ----> 2 df_run_ord = df_run_us.reindex(index=df_run_us.index[ind])
#       3 df_run_ord
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5414                     )
#    5415
# -> 5416         result = getitem(key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
import numpy as np

# 目的：インデックス 3, 4, 5, 6, 0, 1, 2 を並べる
ind = np.append(np.arange(3, 7), np.arange(0, 3))

# 指定した順で並び替え（インデックス位置で選択）
df_run_ord = df_run_us.iloc[ind]
df_run_ord
# Out:
# 性別          女          男
# 学年
# 小1  11.338710  10.725926
# 小2  10.990000  10.582143
# 小3  11.157143  10.246875
# 小4  10.106452   9.595652
# 中1   9.225000   8.458333
# 中2   8.725000   7.875000
# 中3   8.600000   7.841667

# %%
# 50m走が9.5秒以下の人数の割合

def pct_lt(s, thres):
  return s.lt(thres).mean()

df_run_lt = df.groupby(['学年','性別'])['50m走(秒)'].agg(pct_lt, 9.5)
df_run_lt
# Out:
# 学年  性別
# 中1  女     0.833333
#     男     1.000000
# 中2  女     0.833333
#     男     1.000000
# 中3  女     1.000000
#     男     1.000000
# 小1  女     0.032258
#     男     0.000000
# 小2  女     0.000000
#     男     0.000000
# 小3  女     0.107143
#     男     0.187500
# 小4  女     0.161290
#     男     0.565217
# Name: 50m走(秒), dtype: float64

# %%
df_run_lt_ord = df_run_lt.unstack('性別').reindex(index=df_run_us.index[ind])
df_run_lt_ord
# Out:
# 性別         女         男
# 学年
# 小1  0.032258  0.000000
# 小2  0.000000  0.000000
# 小3  0.107143  0.187500
# 小4  0.161290  0.565217
# 中1  0.833333  1.000000
# 中2  0.833333  1.000000
# 中3  1.000000  1.000000

# %%
x_f = np.arange(0.7) - 0.2
x_m = np.arange(0.7) + 0.2

# %%
fig,ax = plt.subplots(figsize=(8,4))
graph_f = ax.bar(x_f, df_run_lt_ord['女'], width=0.4, color = 'pink')
ax.bar_label(graph_f, padding=3)
graph_m = ax.bar(x_m, df_run_lt_ord['男'], width=0.4, color = 'cyan')
ax.bar_label(graph_m, padding=3)
ax.set_ylabel('9.5秒以下の割合')
ax2 = plt.twinx()
ax2.plot(df_run_ord, label=df_run_ord.columns)
ax2.set_ylabel('50m走(秒)')
ax2.legend(loc='upper left')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report

# %%
import keras

# %%
(x_train, y_train),(x_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
print(x_train.shape, x_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)

# %%
cl1 = 1
cl2 = 9
x_train0 = x_train[np.where(y_train==cl1)[0]]
y_train1 = y_train[np.where(y_train==cl2)[0]]
x_test0 = x_test[np.where(y_test==cl1)[0]]
y_test1 = y_test[np.where(y_test==cl2)[0]]

print(x_train0.shape, x_test0.shape)
print(x_train1.shape, x_test1.shape)
# Out:
# (5000, 32, 32, 3) (1000, 32, 32, 3)
# (5000, 32, 32, 3) (1000, 32, 32, 3)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(4, 5, figsize=(10, 8))
ax = ax.flatten()  # ← 関数呼び出しして、1次元配列に変換

for i in range(10):
    ax[i].imshow(x_train0[i])
    ax[i].axis('off')

    ax[i + 10].imshow(x_train1[i])
    ax[i + 10].axis('off')

    ax[i].imshow(x_test1[i])
    ax[i].axis('off')

    ax[i + 10].imshow(x_test1[i])
    ax[i + 10].axis('off')

# %%
x_tr = np.vstack((x_train0[:500],x_train1[:500]))
x_te = np.vstack((x_test0[:100],x_test1[:100]))
y_tr = np.vstack((np.zeros(500,1,int),np.ones((500,1).int)))
y_te = np.vstack((np.zeros(100,1,int),np.ones((100,1).int)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-e21d274aef50> in <cell line: 0>()
#       1 x_tr = np.vstack((x_train0[:500],x_train1[:500]))
#       2 x_te = np.vstack((x_test0[:100],x_test1[:100]))
# ----> 3 y_tr = np.vstack((np.zeros(500,1,int),np.ones((500,1).int)))
#       4 y_te = np.vstack((np.zeros(100,1,int),np.ones((100,1).int)))
#
# TypeError: Cannot interpret '1' as a data type

# %%
x_tr = x_tr.reshape(x_tr.shape[0],-1)
x_te = x_te.reshape(x_tr.shape[0],-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-ce2c4fa668be> in <cell line: 0>()
#       1 x_tr = x_tr.reshape(x_tr.shape[0],-1)
# ----> 2 x_te = x_te.reshape(x_tr.shape[0],-1)
#
# ValueError: cannot reshape array of size 614400 into shape (1000,newaxis)

# %%
x_tr.shape
# Out:
# (1000, 3072)

# %%
pca = PCA(n_components=2)
train_pca = pca.fit_transform(x_tr)
test_pca = pca.transform(x_te)
train_pca.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-4d7c739e83f2> in <cell line: 0>()
#       1 pca = PCA(n_components=2)
#       2 train_pca = pca.fit_transform(x_tr)
# ----> 3 test_pca = pca.transform(x_te)
#       4 train_pca.shape
#       5
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/decomposition/_base.py in transform(self, X)
#     136         check_is_fitted(self)
#     137
# --> 138         X = validate_data(
#     139             self,
#     140             X,
#
# ...

# %%
k = 3
knn = KNeighborsClassifier(train_pca,y_tr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-e74cd818eeb0> in <cell line: 0>()
#       1 k = 3
# ----> 2 knn = KNeighborsClassifier(train_pca,y_tr)
#
# NameError: name 'y_tr' is not defined

# %%
pr_te = knn.predict(test_pca)
print(confusion_matrix(y_te,pr_te))
print(classification_report(y_te,pr_te))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-0e0aab90df9e> in <cell line: 0>()
# ----> 1 pr_te = knn.predict(test_pca)
#       2 print(confusion_matrix(y_te,pr_te))
#       3 print(classification_report(y_te,pr_te))
#
# NameError: name 'knn' is not defined

# %%
#特徴量数の変更
#1．pca の次元数を変更
#2. 画像のサイズを落とす

# %%
from PIL import Image

# %%
w = h = 16
x_tr_sm = np.zeros((x_tr.shape[0], h, w, 3))

for i,smp in enumerate(t_tr):
  img = Image.fromarray(smp.reshap(32,32,3))
  img = img.resize(w,h), Image.LANCZOS
  x_tr_su[i] = np.array(img, np.uint8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-656a0f116056> in <cell line: 0>()
#       2 x_tr_sm = np.zeros((x_tr.shape[0], h, w, 3))
#       3
# ----> 4 for i,smp in enumerate(t_tr):
#       5   img = Image.fromarray(smp.reshap(32,32,3))
#       6   img = img.resize(w,h), Image.LANCZOS
#
# NameError: name 't_tr' is not defined

# %%
x_tr_sm.shape
# Out:
# (1000, 16, 16, 3)

# %%
x_te_sm = np.zeros((x_te.shape))

# %%
# 失敗ケース
failed = []
for i, (y_te, pr_te) in enumerate(zip(y_te, pr_te)):
  if y_true != y_pred:
    failed.append(i)
print(failed[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-834e4befcb20> in <cell line: 0>()
#       1 # 失敗ケース
#       2 failed = []
# ----> 3 for i, (y_te, pr_te) in enumerate(zip(y_te, pr_te)):
#       4   if y_true != y_pred:
#       5     failed.append(i)
#
# NameError: name 'y_te' is not defined

# %%
f = 1
fig,ax = plt.subplots(figsize=(8,8))

# %%
# 図の拡大
ax.set xlim(333,555)

# %%
# 円を描く
red = np.linspase(-ne_pi,200)
r = 100
ax.plot(r*np.cos(red)+test_pca r*np.sin(red), color='red

# %%
# 課題のcvはグリッドサーチOK　→
#　結果を可視化する。円をかく
アキュラシー、ROC、精度、Recall、
（期限は１か月）

Jupyter notebookをhtmlで提出
コードと結果が両方見えている状態で提出

クロスバリデーション　→　テストデータへの適応
